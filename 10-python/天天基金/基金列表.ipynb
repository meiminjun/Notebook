# %% [markdown]
# # 天天基金爬取基金

# %%
import requests
# import re
from lxml import etree
from fake_useragent import UserAgent



# url = 'https://fund.eastmoney.com/'

# url = 'http://fund.eastmoney.com/data/fundranking.html#tall;c0;r;s1nzf;pn50;ddesc;qsd20210910;qed20220910;qdii;zq;gg;gzbd;gzfs;bbzt;sfbb'
url = 'http://fund.eastmoney.com/data/fundranking.html#tall;c0;r;s1nzf;pn50;ddesc;qsd20210910;qed20220910;qdii;zq;gg;gzbd;gzfs;bbzt;sfbb'

headers = {
    "Accept": "text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.9",
    "Accept-Encoding": "gzip, deflate",
    "Accept-Language": "zh-CN,zh;q=0.9",
    "Cache-Control": "no-cache",
    "Connection": "keep-alive",
    # "Host": "97.push2.eastmoney.com",
    "Pragma": "no-cache",
    # "Upgrade-Insecure-Requests": "1",
    "User-Agent": UserAgent().random
}



response = requests.get(url, headers=headers, verify=False)
# print(response.text)

html = etree.HTML(response.text)
print(etree.tostring(html))
code = html.xpath('//*[@id="dbtable"]/tbody/tr/td[3]/a')
print(code)
# print(html)
# pattern = re.compile(r'.*?"(?P<items>.*?)".*?', re.S)
# result = re.finditer(pattern, response.text)
# ids = []
# for item in result:
# print(item.group('items'))
# gp_id = item.group('items').split(',')[0]
# print(gp_id)
# Out:
# b'<html xmlns="http://www.w3.org/1999/xhtml"><body><p>&#239;&#187;&#191;&#13;\n&#13;\n&#13;\n&#13;\n</p>&#13;\n    <title>&#229;&#188;&#128;&#230;&#148;&#190;&#229;&#188;&#143;&#229;&#159;&#186;&#233;&#135;&#145;&#230;&#142;&#146;&#232;&#161;&#140; _ &#229;&#164;&#169;&#229;&#164;&#169;&#229;&#159;&#186;&#233;&#135;&#145;&#231;&#189;&#145;</title>&#13;\n    <meta name="keywords" content="&#229;&#159;&#186;&#233;&#135;&#145;&#230;&#142;&#146;&#232;&#161;&#140;,&#229;&#188;&#128;&#230;&#148;&#190;&#229;&#188;&#143;&#229;&#159;&#186;&#233;&#135;&#145;&#230;&#142;&#146;&#232;&#161;&#140;,&#229;&#136;&#155;&#230;&#150;&#176;&#229;&#159;&#186;&#233;&#135;&#145;&#230;&#142;&#146;&#232;&#161;&#140;,&#232;&#180;&#167;&#229;&#184;&#129;&#229;&#159;&#186;&#233;&#135;&#145;&#230;&#142;&#146;&#232;&#161;&#140;,&#230;&#182;&#168;&#229;&#185;&#133;&#230;&#142;&#146;&#232;&#161;&#140;,&#229;&#159;&#186;&#233;&#135;&#145;&#230;&#142;&#146;&#232;&#161;&#140;&#230;&#159;&#165;&#232;&#175;&#162;,&#230;&
# ...
