# %% [markdown]
# # 爬取上市公司相关信息

# %% [markdown]
# ## 简单版本
#
# 缺点：遇到错误异常就会终止

# %%
import pandas as pd
import csv
for i in range(1,178):  # 爬取全部页
    tb = pd.read_html('http://s.askci.com/stock/a/?reportTime=2017-12-31&pageNum=%s' % (str(i)))[3] 
    tb.to_csv(r'1.csv', mode='a', encoding='utf_8_sig', header=1, index=0)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/w6/9k4dzqlj617f06dfby_vk1pr0000gn/T/ipykernel_33099/3078076881.py in <module>
#       2 import csv
#       3 for i in range(1,178):  # 爬取全部页
# ----> 4     tb = pd.read_html('http://s.askci.com/stock/a/?reportTime=2017-12-31&pageNum=%s' % (str(i)))[3]
#       5     tb.to_csv(r'1.csv', mode='a', encoding='utf_8_sig', header=1, index=0)
#
# /usr/local/anaconda3/envs/py39/lib/python3.9/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# /usr/local/anaconda3/envs/py39/lib/python3.9/site-packages/pandas/io/html.py in read_html(io, match, flavor, header, index_col, skiprows, attrs, parse_dates, thousands, encoding, decimal, converters, na_values, keep_default_na, displayed_only)
#    1096     io = stringify_path(io)
#    1097
# -> 1098     return _parse(
#    1099         flavor=flavor,
#    1100         io=io,
#
# /usr/local/anaconda3/envs/py39/lib/python3.9/site-packages/pandas/io/html.py in _parse(flavor, io, match, attrs, encoding, displayed_only, **kwargs)
#     924     else:
#     925         assert retained is not None  # for mypy
# --> 926         raise retained
#     927
#     928     ret = []
#
# /usr/local/anaconda3/envs/py39/lib/python3.9/site-packages/pandas/io/html.py in _parse(flavor, io, match, attrs, encoding, displayed_only, **kwargs)
#     904
#     905         try:
# --> 906             tables = p.parse_tables()
#     907         except ValueError as caught:
#     908             # if `io` is an io-like object, check if it's seekable
#
# /usr/local/anaconda3/envs/py39/lib/python3.9/site-packages/pandas/io/html.py in parse_tables(self)
#     220         list of parsed (header, body, footer) tuples from tables.
#     221         """
# --> 222         tables = self._parse_tables(self._build_doc(), self.match, self.attrs)
#     223         return (self._parse_thead_tbody_tfoot(table) for table in tables)
#     224
#
# /usr/local/anaconda3/envs/py39/lib/python3.9/site-packages/pandas/io/html.py in _parse_tables(self, doc, match, attrs)
#     550
#     551         if not tables:
# --> 552             raise ValueError("No tables found")
#     553
#     554         result = []
#
# ValueError: No tables found

# %% [markdown]
# ## 完整版本

# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup
from lxml import etree
import time
import pymysql
from sqlalchemy import create_engine
from urllib.parse import urlencode  # 编码 URL 字符串
from multiprocessing import Pool


start_time = time.time()  #计算程序运行时间


def get_one_page(i):
    try:
        headers = {
            'User-Agent': 'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/66.0.3359.181 Safari/537.36'
        }
        paras = {
        'reportTime': '2017-12-31',
        #可以改报告日期，比如2018-6-30获得的就是该季度的信息
        'pageNum': i   #页码
        }
        url = 'http://s.askci.com/stock/a/?' + urlencode(paras)
        response = requests.get(url,headers = headers)
        if response.status_code == 200:
            return response.text
        return None
    except RequestException:
        print('爬取失败')


def parse_one_page(html):
    soup = BeautifulSoup(html,'lxml')
    content = soup.select('#myTable04')[0] #[0]将返回的list改为bs4类型
    tbl = pd.read_html(content.prettify(),header = 0)[0]
    # prettify()优化代码,[0]从pd.read_html返回的list中提取出DataFrame
    tbl.rename(columns = {'序号':'serial_number', '股票代码':'stock_code', '股票简称':'stock_abbre', '公司名称':'company_name', '省份':'province', '城市':'city', '主营业务收入(201712)':'main_bussiness_income', '净利润(201712)':'net_profit', '员工人数':'employees', '上市日期':'listing_date', '招股书':'zhaogushu', '公司财报':'financial_report', '行业分类':'industry_classification', '产品类型':'industry_type', '主营业务':'main_business'},inplace = True)
    return tbl


def generate_mysql():
    conn = pymysql.connect(
        host='localhost',
        user='root',
        password='123456',
        port=3306,
        charset = 'utf8',
        db = 'stock')
    cursor = conn.cursor()


    sql = 'CREATE TABLE IF NOT EXISTS listed_company (serial_number INT(20) NOT NULL,stock_code INT(20) ,stock_abbre VARCHAR(20) ,company_name VARCHAR(20) ,province VARCHAR(20) ,city VARCHAR(20) ,main_bussiness_income VARCHAR(20) ,net_profit VARCHAR(20) ,employees INT(20) ,listing_date DATETIME(0) ,zhaogushu VARCHAR(20) ,financial_report VARCHAR(20) , industry_classification VARCHAR(20) ,industry_type VARCHAR(100) ,main_business VARCHAR(200) ,PRIMARY KEY (serial_number))'
    cursor.execute(sql)
    conn.close()


def write_to_sql(tbl, db='stock'):
    # engine = create_engine('mysql+pymysql://root:******@localhost:3306/{0}?charset=utf8'.format(db))
    engine = create_engine('mysql+pymysql://root:123456@localhost:3306/{0}?charset=utf8'.format(db))
    try:
        tbl.to_sql('listed_company',con = engine,if_exists='append',index=False)
        # append表示在原有表基础上增加，但该表要有表头
    except Exception as e:
        print(e)


def main(page):
    generate_mysql()
    for i in range(1,page):
        html = get_one_page(i)
        tbl = parse_one_page(html)
        write_to_sql(tbl)


# 单进程
if __name__ == '__main__':
    main(178)
    endtime = time.time()-start_time
    print('程序运行了%.2f秒' %endtime)


# 多进程
# if __name__ == '__main__':
#     pool = Pool(4)
#     pool.map(main, [i for i in range(1,178)])  #共有178页
#     endtime = time.time()-start_time
#     print('程序运行了%.2f秒' %(endtime))
# Out:
# (pymysql.err.DataError) (1406, "Data too long for column 'industry_type' at row 3")
# [SQL: INSERT INTO listed_company (serial_number, stock_code, stock_abbre, company_name, province, city, main_bussiness_income, net_profit, employees, listing_date, zhaogushu, financial_report, industry_classification, industry_type, main_business) VALUES (%(serial_number)s, %(stock_code)s, %(stock_abbre)s, %(company_name)s, %(province)s, %(city)s, %(main_bussiness_income)s, %(net_profit)s, %(employees)s, %(listing_date)s, %(zhaogushu)s, %(financial_report)s, %(industry_classification)s, %(industry_type)s, %(main_business)s)]
# [parameters: ({'serial_number': 1, 'stock_code': 1, 'stock_abbre': '平安银行', 'company_name': '平安银行股份有限公司', 'province': '广东', 'city': '深圳市', 'main_bussiness_income': '1057.86亿', 'net_profit': '231.89亿', 'employees': 40745, 'listing_date': '1991-04-03', 'zhaogushu': '--', 'financial_report': None, 'industry_classification': '银行', 'industry_type': '商业银行业务', 'main_business': '经有关监管机构批准的各项商业银行业务。'}, {'serial_number': 2, 'stock_code': 2, 'stock_abbre': '万科A', 'company_name': '万科企业股份有限公司', 'province': '广东', 'city': '深圳市', 'main_bussiness_income': '2428.97亿', 'net_profit': '372.08亿', 'employees': 130292, 'listing_date': '1991-01-29', 'zhaogushu': '--', 'financial_report': None, 'industry_classification': '房地产开发', 'industry_type': '房地产、物业管理、投资咨询', 'main_business': '房地产开发和物业服务。'}, {'serial_number': 3, 'stock_code': 4, 'stock_abbre': 'ST国华', 'company_name': '深圳国华网安科技股份有限公司', 'province': '广东', 'city': '深圳市', 'main_bussiness_income': '1.39亿', 'net_profit': '589.22万', 'employees': 309, 'listing_date': '1991-01-14', 'zhaogushu': '--', 'financial_report': None, 'industry_classification': '生物医药', 'industry_type': '应急类产品、安全加固检测类、安全检测类产品、集成产品、智慧类产品、移动应用安全检测平台、移动应用安全加固平台、威胁态势感知平台、其他平台、安全管理平台、源代码审计平台、定制开发产品、其他产品、游戏类产品', 'main_business': '移动互联网安全、智慧城市及应急业务。'}, {'serial_number': 4, 'stock_code': 5, 'stock_abbre': 'ST星源', 'company_name': '深圳世纪星源股份有限公司', 'province': '广东', 'city': '深圳市', 'main_bussiness_income': '5.31亿', 'net_profit': '2293.60万', 'employees': 563, 'listing_date': '1990-12-10', 'zhaogushu': '--', 'financial_report': None, 'industry_classification': '环保工程、物业管理', 'industry_type': '酒店经营、物业管理、环保业务', 'main_business': '绿色低碳城市社区建设相关的服务业务。'}, {'serial_number': 5, 'stock_code': 6, 'stock_abbre': '深振业A', 'company_name': '深圳市振业(集团)股份有限公司', 'province': '广东', 'city': '深圳市', 'main_bussiness_income': '29.59亿', 'net_profit': '8.20亿', 'employees': 403, 'listing_date': '1992-04-27', 'zhaogushu': '--', 'financial_report': None, 'industry_classification': '房地产开发', 'industry_type': '房地产', 'main_business': '从事房地产开发与销售。'}, {'serial_number': 6, 'stock_code': 7, 'stock_abbre': '全新好', 'company_name': '深圳市全新好股份有限公司', 'province': '广东', 'city': '深圳市', 'main_bussiness_income': '3964.40万', 'net_profit': '79.51万', 'employees': 82, 'listing_date': '1992-04-13', 'zhaogushu': '--', 'financial_report': None, 'industry_classification': '物业经营', 'industry_type': '物业管理、房屋租赁、汽车经销业、大健康产业', 'main_business': '物业管理和房屋租赁业、汽车经销业、大健康产业。'}, {'serial_number': 7, 'stock_code': 8, 'stock_abbre': '神州高铁', 'company_name': '神州高铁技术股份有限公司', 'province': '北京', 'city': '北京市', 'main_bussiness_income': '23.31亿', 'net_profit': '8.90亿', 'employees': 2240, 'listing_date': '1992-05-07', 'zhaogushu': '--', 'financial_report': None, 'industry_classification': '轨道交通设备', 'industry_type': '轨道交通', 'main_business': '专业致力于提供轨道交通运营检修装备与数据、线路运营、维保服务。'}, {'serial_number': 8, 'stock_code': 9, 'stock_abbre': '中国宝安', 'company_name': '中国宝安集团股份有限公司', 'province': '广东', 'city': '深圳市', 'main_bussiness_income': '70.71亿', 'net_profit': '3.23亿', 'employees': 14335, 'listing_date': '1991-06-25', 'zhaogushu': '--', 'financial_report': None, 'industry_classification': '综合', 'industry_type': '高新技术产业、生物医药、房地产', 'main_business': '高新技术产业、生物医药产业、房地产及其他产业。'}  ... displaying 10 of 20 total bound parameter sets ...  {'serial_number': 19, 'stock_code': 25, 'stock_abbre': '特力A', 'company_name': '深圳市特力(集团)股份有限公司', 'province': '广东', 'city': '深圳市', 'main_bussiness_income': '3.47亿', 'net_profit': '6578.16万', 'employees': 298, 'listing_date': '1993-06-21', 'zhaogushu': '--', 'financial_report': None, 'industry_classification': '汽车销售', 'industry_type': '汽车销售、汽车检测维修及配件销售、物业租赁及服务、珠宝批发及零售', 'main_business': '珠宝服务业务；商业运营管理；汽车销售、检测、维修及配件销售。'}, {'serial_number': 20, 'stock_code': 26, 'stock_abbre': '飞亚达', 'company_name': '飞亚达精密科技股份有限公司', 'province': '广东', 'city': '深圳市', 'main_bussiness_income': '33.46亿', 'net_profit': '1.43亿', 'employees': 5081, 'listing_date': '1993-06-03', 'zhaogushu': '--', 'financial_report': None, 'industry_classification': '珠宝首 ...
# (Background on this error at: https://sqlalche.me/e/14/9h9h)
# (pymysql.err.IntegrityError) (1062, "Duplicate entry '21' for key 'PRIMARY'")
# [SQL: INSERT INTO listed_company (serial_number, stock_code, stock_abbre, company_name, province, city, main_bussiness_income, net_profit, employees, listing_date, zhaogushu, financial_report, industry_classification, industry_type, main_business) VALUES (%(serial_number)s, %(stock_code)s, %(stock_abbre)s, %(company_name)s, %(province)s, %(city)s, %(main_bussiness_income)s, %(net_profit)s, %(employees)s, %(listing_date)s, %(zhaogushu)s, %(financial_report)s, %(industry_classification)s, %(industry_type)s, %(main_business)s)]
# [parameters: ({'serial_number': 21, 'stock_code': 27, 'stock_abbre': '深圳能源', 'company_name': '深圳能源集团股份有限公司', 'province': '广东', 'city': '深圳市', 'main_bussiness_income': '155.46亿', 'net_profit': '8.45亿', 'employees': 12808, 'listing_date': '1993-09-03', 'zhaogushu': '--', 'financial_report': None, 'industry_classification': '火电', 'industry_type': '燃煤、燃机、水电、风电、生态环保、综合燃气', 'main_business': '各种常规能源和新能源的开发、生产、购销，以及城市固体废物处理、废水处理和城市燃气供应等。'}, {'serial_number': 22, 'stock_code': 28, 'stock_abbre': '国药一致', 'company_name': '国药集团一致药业股份有限公司', 'province': '广东', 'city': '深圳市', 'main_bussiness_income': '412.63亿', 'net_profit': '11.57亿', 'employees': 39386, 'listing_date': '1993-08-09', 'zhaogushu': '--', 'financial_report': None, 'industry_classification': '医药商业', 'industry_type': '药品、器械耗材、诊断试剂、仪器设备', 'main_business': '医药分销和医药零售。'}, {'serial_number': 23, 'stock_code': 29, 'stock_abbre': '深深房A', 'company_name': '深圳经济特区房地产(集团)股份有限公司', 'province': '广东', 'city': '深圳市', 'main_bussiness_income': '13.46亿', 'net_profit': '1.85亿', 'employees': 1578, 'listing_date': '1993-09-15', 'zhaogushu': '--', 'financial_report': None, 'industry_classification': '房地产开发', 'industry_type': '住宅、商铺、车位', 'main_business': '住宅地产开发。'}, {'serial_number': 24, 'stock_code': 30, 'stock_abbre': '富奥股份', 'company_name': '富奥汽车零部件股份有限公司', 'province': '吉林', 'city': '长春市', 'main_bussiness_income': '71.93亿', 'net_profit': '8.19亿', 'employees': 7695, 'listing_date': '1993-09-29', 'zhaogushu': '--', 'financial_report': None, 'industry_classification': '汽车零部件', 'industry_type': '零部件', 'main_business': '汽车零部件的研发、生产和销售。'}, {'serial_number': 25, 'stock_code': 31, 'stock_abbre': '大悦城', 'company_name': '大悦城控股集团股份有限公司', 'province': '广东', 'city': '深圳市', 'main_bussiness_income': '140.42亿', 'net_profit': '17.35亿', 'employees': 10186, 'listing_date': '1993-10-08', 'zhaogushu': '--', 'financial_report': None, 'industry_classification': '房地产开发', 'industry_type': '商品房销售、一级土地开发、投资物业及相关服务、酒店经营、物业及其他管理', 'main_business': '房地产开发、经营、销售、出租及管理住宅、商用物业，经营业态涵盖住宅、商业地产及部分产业地产。'}, {'serial_number': 26, 'stock_code': 32, 'stock_abbre': '深桑达A', 'company_name': '深圳市桑达实业股份有限公司', 'province': '广东', 'city': '深圳市', 'main_bussiness_income': '18.82亿', 'net_profit': '5525.24万', 'employees': 20696, 'listing_date': '1993-10-28', 'zhaogushu': '--', 'financial_report': None, 'industry_classification': '电子物流', 'industry_type': '电子信息、房地产及租赁、电子商贸、电子物流', 'main_business': '电子制造、电子商贸、电子物流服务等在内的一体化现代电子信息服务。'}, {'serial_number': 27, 'stock_code': 34, 'stock_abbre': '神州数码', 'company_name': '神州数码集团股份有限公司', 'province': '广东', 'city': '深圳市', 'main_bussiness_income': '622.16亿', 'net_profit': '7.23亿', 'employees': 5210, 'listing_date': '1994-05-09', 'zhaogushu': '--', 'financial_report': None, 'industry_classification': '贸易', 'industry_type': '云计算和数字化转型业务、信息技术应用创新业务', 'main_business': '云计算和数字化转型业务、信息技术应用创新业务、信息技术应用创新业务。'}, {'serial_number': 28, 'stock_code': 35, 'stock_abbre': '中国天楹', 'company_name': '中国天楹股份有限公司', 'province': '江苏', 'city': '南通市', 'main_bussiness_income': '16.12亿', 'net_profit': '2.25亿', 'employees': 15326, 'listing_date': '1994-04-08', 'zhaogushu': '--', 'financial_report': None, 'industry_classification': '垃圾发电', 'industry_type': '综合城市环境服务、废弃物处置与利用、水务综合管理、工业废弃物处置、环保装备制造', 'main_business': '综合城市环境服务、废弃物处置与利用、水务综合管理、工业废弃物处置和环保装备制造。'}  ... displaying 10 of 20 total bound parameter sets ...  {'serial_number': 39, 'stock_code': 50, 'stock_abbre': '深天马A', 'company_name': '天马微电子股份有限公司', 'province': '广东', 'city': '深圳市', 'main_bussiness_income': '238.24亿', 'net_profit': '15.35亿', 'employees': 26797, 'listing_date': '1995-03-15', 'zhaogushu': '--', 'financial_report': None, 'industry_classification': '显示器件', 'industry_type': '电子元器件', 'main_business': '从事显示器件及相关的材料、设备、产品的设计、制造、销售。'}, {'serial_number': 40, 'stock_code': 55, 'stock_abbre': '方大集团', 'company_name': '方大集团股份有限公司', 'province': '广东', 'city': '深圳市', 'main_bussiness_income': '29.47亿', 'net_profit': '11.51亿', 'employees': 2959, 'listing_date': '1996-04-15', 'zhaogushu': '--', 'fin ...
# (Background on this error at: https://sqlalche.me/e/14/gkpj)
# (pymysql.err.IntegrityError) (1062, "Duplicate entry '41' for key 'PRIMARY'")
# [SQL: INSERT INTO listed_company (serial_number, stock_code, stock_abbre, company_name, province, city, main_bussiness_income, net_profit, employees, listing_date, zhaogushu, financial_report, industry_classification, industry_type, main_business) VALUES (%(serial_number)s, %(stock_code)s, %(stock_abbre)s, %(company_name)s, %(province)s, %(city)s, %(main_bussiness_income)s, %(net_profit)s, %(employees)s, %(listing_date)s, %(zhaogushu)s, %(financial_report)s, %(industry_classification)s, %(industry_type)s, %(main_business)s)]
# [parameters: ({'serial_number': 41, 'stock_code': 56, 'stock_abbre': '皇庭国际', 'company_name': '深圳市皇庭国际企业股份有限公司', 'province': '广东', 'city': '深圳市', 'main_bussiness_income': '8.08亿', 'net_profit': '1.52亿', 'employees': 837, 'listing_date': '1996-07-08', 'zhaogushu': '--', 'financial_report': None, 'industry_classification': '物业租赁、物业管理', 'industry_type': '商业运营服务、金融服务、融资租赁服务', 'main_business': '商业不动产运营管理业务、资产管理业务以及各配套服务业务。'}, {'serial_number': 42, 'stock_code': 58, 'stock_abbre': '深赛格', 'company_name': '深圳赛格股份有限公司', 'province': '广东', 'city': '深圳市', 'main_bussiness_income': '20.30亿', 'net_profit': '3.08亿', 'employees': 11590, 'listing_date': '1996-12-26', 'zhaogushu': '--', 'financial_report': None, 'industry_classification': '专业市场', 'industry_type': '电子市场流通、智慧城市及城市服务、检验检测业务、新能源业务', 'main_business': '以通信市场、电子专业市场为核心的电子市场流通业务，以检验检测与新能源为核心的战略性新兴业务，以物业经营及管理服务为核心的智慧城市及城市服务业务。'}, {'serial_number': 43, 'stock_code': 59, 'stock_abbre': '华锦股份', 'company_name': '北方华锦化学工业股份有限公司', 'province': '辽宁', 'city': '盘锦市', 'main_bussiness_income': '337.14亿', 'net_profit': '19.41亿', 'employees': 8056, 'listing_date': '1997-01-30', 'zhaogushu': '--', 'financial_report': None, 'industry_classification': '石油加工', 'industry_type': '原油加工及石油制品、聚烯烃类产品', 'main_business': '石油化工产品、化学肥料的生产与销售。'}, {'serial_number': 44, 'stock_code': 60, 'stock_abbre': '中金岭南', 'company_name': '深圳市中金岭南有色金属股份有限公司', 'province': '广东', 'city': '深圳市', 'main_bussiness_income': '190.16亿', 'net_profit': '10.94亿', 'employees': 9664, 'listing_date': '1997-01-23', 'zhaogushu': '--', 'financial_report': None, 'industry_classification': '铅锌', 'industry_type': '精矿产品、冶炼产品、铝型材、幕墙门窗、电池材料、有色金属贸易业务', 'main_business': '铅锌铜等有色金属的采矿、选矿、冶炼和深加工。'}, {'serial_number': 45, 'stock_code': 61, 'stock_abbre': '农产品', 'company_name': '深圳市农产品集团股份有限公司', 'province': '广东', 'city': '深圳市', 'main_bussiness_income': '24.46亿', 'net_profit': '6117.25万', 'employees': 4807, 'listing_date': '1997-01-10', 'zhaogushu': '--', 'financial_report': None, 'industry_classification': '专业市场', 'industry_type': '农产品流通、农产品供应链服务、农产品电子商务', 'main_business': '农产品批发市场的开发、建设、经营和管理，大宗农产品电子交易和蔬菜种植等。'}, {'serial_number': 46, 'stock_code': 62, 'stock_abbre': '深圳华强', 'company_name': '深圳华强实业股份有限公司', 'province': '广东', 'city': '深圳市', 'main_bussiness_income': '85.46亿', 'net_profit': '4.64亿', 'employees': 2246, 'listing_date': '1997-01-30', 'zhaogushu': '--', 'financial_report': None, 'industry_classification': '专业市场', 'industry_type': '电子元器件授权分销分部、电子元器件产业互联网分部、电子元器件及电子终端产品实体交易市场分部、物业经营及其他分部', 'main_business': '面向电子信息产业链的现代高端服务业，为产业链上的各环节提供线上线下交易服务、产品服务、技术服务、信息服务、数据服务和创新创业配套等服务，打造面向电子信息产业的国内一流线下、线上交易服务平台。'}, {'serial_number': 47, 'stock_code': 63, 'stock_abbre': '中兴通讯', 'company_name': '中兴通讯股份有限公司', 'province': '广东', 'city': '深圳市', 'main_bussiness_income': '1088.15亿', 'net_profit': '53.86亿', 'employees': 73191, 'listing_date': '1997-11-18', 'zhaogushu': '--', 'financial_report': None, 'industry_classification': '通信传输设备', 'industry_type': '运营商网络、消费者业务、政企业务', 'main_business': '致力于为客户提供满意的ICT产品及解决方案，集“设计、开发、生产、销售、服务”等一体，聚焦于“运营商网络、政企业务、消费者业务”。'}, {'serial_number': 48, 'stock_code': 65, 'stock_abbre': '北方国际', 'company_name': '北方国际合作股份有限公司', 'province': '北京', 'city': '北京市', 'main_bussiness_income': '97.30亿', 'net_profit': '5.43亿', 'employees': 1911, 'listing_date': '1998-06-05', 'zhaogushu': '--', 'financial_report': None, 'industry_classification': '专业工程', 'industry_type': '国际工程承包、国内建筑工程、货物贸易、货运代理、金属包装容器、发电收入、其他', 'main_business': '国际工程承包、国内建筑工程、重型装备出口贸易、物流服务、物流自动化设备系统集成服务、太阳能产品贸易及新能源项目开发、大宗商品贸易和金属包装容器的生产和销售。'}  ... displaying 10 of 20 total bound parameter sets ...  {'serial_number': 59, 'stock_code': 100, 'stock_abbre': 'TCL科技', 'company_name': 'TCL科技集团股份有限公司', 'province': '广东', 'city': '惠州市', 'main_bussiness_income': '1117.27亿', 'net_profit': '35.45亿', 'employees': 65159, 'listing_date': '2004-01-30', 'zhaogushu': '--', 'financial_report': None, 'industry_classification': '电视机', 'industry_type': '半导体显示业务、半导体光伏及半导体材料业务、产业金融及投资平台', 'main_business': '半导体显示业务,半导体光伏及 ...
# (Background on this error at: https://sqlalche.me/e/14/gkpj)
# (pymysql.err.IntegrityError) (1062, "Duplicate entry '61' for key 'PRIMARY'")
# [SQL: INSERT INTO listed_company (serial_number, stock_code, stock_abbre, company_name, province, city, main_bussiness_income, net_profit, employees, listing_date, zhaogushu, financial_report, industry_classification, industry_type, main_business) VALUES (%(serial_number)s, %(stock_code)s, %(stock_abbre)s, %(company_name)s, %(province)s, %(city)s, %(main_bussiness_income)s, %(net_profit)s, %(employees)s, %(listing_date)s, %(zhaogushu)s, %(financial_report)s, %(industry_classification)s, %(industry_type)s, %(main_business)s)]
# [parameters: ({'serial_number': 61, 'stock_code': 151, 'stock_abbre': '中成股份', 'company_name': '中成进出口股份有限公司', 'province': '北京', 'city': '北京市', 'main_bussiness_income': '22.29亿', 'net_profit': '8843.59万', 'employees': 1154, 'listing_date': '2000-09-06', 'zhaogushu': '--', 'financial_report': None, 'industry_classification': '贸易', 'industry_type': '成套设备出口和工程承包、一般贸易、境外实业经营', 'main_business': '成套设备与技术进出口、一般贸易和境外经营。'}, {'serial_number': 62, 'stock_code': 153, 'stock_abbre': '丰原药业', 'company_name': '安徽丰原药业股份有限公司', 'province': '安徽', 'city': '合肥市', 'main_bussiness_income': '25.78亿', 'net_profit': '6534.81万', 'employees': 4538, 'listing_date': '2000-09-20', 'zhaogushu': '--', 'financial_report': None, 'industry_classification': '化学制剂', 'industry_type': '注射剂、粉针类、散剂、片剂、胶囊剂、颗粒剂、贴剂、原料药', 'main_business': '生物药、化学药及中药的研发、生产和销售；医药配送和药房零售。'}, {'serial_number': 63, 'stock_code': 155, 'stock_abbre': '川能动力', 'company_name': '四川省新能源动力股份有限公司', 'province': '四川', 'city': '成都市', 'main_bussiness_income': '65.09亿', 'net_profit': '3.82亿', 'employees': 2933, 'listing_date': '2000-09-26', 'zhaogushu': '--', 'financial_report': None, 'industry_classification': '氮肥', 'industry_type': '新能源综合服务业务、电力销售', 'main_business': '新能源发电业务，即风力发电、光伏发电项目开发、建设和运营。'}, {'serial_number': 64, 'stock_code': 156, 'stock_abbre': '华数传媒', 'company_name': '华数传媒控股股份有限公司', 'province': '浙江', 'city': '杭州市', 'main_bussiness_income': '32.09亿', 'net_profit': '6.41亿', 'employees': 12057, 'listing_date': '2000-09-06', 'zhaogushu': '--', 'financial_report': None, 'industry_classification': '有线电视', 'industry_type': '信息传播', 'main_business': '有线电视网络业务、全国范围内的新媒体业务、宽带网络及智慧城市业务等。'}, {'serial_number': 65, 'stock_code': 157, 'stock_abbre': '中联重科', 'company_name': '中联重科股份有限公司', 'province': '湖南', 'city': '长沙市', 'main_bussiness_income': '232.73亿', 'net_profit': '12.48亿', 'employees': 26036, 'listing_date': '2000-10-12', 'zhaogushu': '--', 'financial_report': None, 'industry_classification': '工程机械', 'industry_type': '工程机械、农业机械、金融服务', 'main_business': '工程机械和农业机械的研发、制造、销售和服务。'}, {'serial_number': 66, 'stock_code': 158, 'stock_abbre': '常山北明', 'company_name': '石家庄常山北明科技股份有限公司', 'province': '河北', 'city': '石家庄市', 'main_bussiness_income': '112.54亿', 'net_profit': '3.55亿', 'employees': 5068, 'listing_date': '2000-07-24', 'zhaogushu': '--', 'financial_report': None, 'industry_classification': '棉纺', 'industry_type': '纺织、软件和信息技术服务', 'main_business': '软件及信息技术服务和纺织两大板块。'}, {'serial_number': 67, 'stock_code': 159, 'stock_abbre': '国际实业', 'company_name': '新疆国际实业股份有限公司', 'province': '新疆', 'city': '乌鲁木齐市', 'main_bussiness_income': '3.56亿', 'net_profit': '-7113.14万', 'employees': 547, 'listing_date': '2000-09-26', 'zhaogushu': '--', 'financial_report': None, 'industry_classification': '石油天然气贸易', 'industry_type': '油品销售、房地产销售、仓储服务', 'main_business': '油品等能源产品的采购、批发、仓储、铁路专运。'}, {'serial_number': 68, 'stock_code': 166, 'stock_abbre': '申万宏源', 'company_name': '申万宏源集团股份有限公司', 'province': '新疆', 'city': '乌鲁木齐市', 'main_bussiness_income': '133.68亿', 'net_profit': '47.26亿', 'employees': 11547, 'listing_date': '2015-01-26', 'zhaogushu': '--', 'financial_report': None, 'industry_classification': '证券', 'industry_type': '企业金融业务、个人金融业务、机构服务及交易业务、投资管理业务', 'main_business': '金融投资、股权投资等。'}  ... displaying 10 of 20 total bound parameter sets ...  {'serial_number': 79, 'stock_code': 409, 'stock_abbre': '云鼎科技', 'company_name': '云鼎科技股份有限公司', 'province': '山东', 'city': '济南市', 'main_bussiness_income': '14.30亿', 'net_profit': '-2.71亿', 'employees': 643, 'listing_date': '1996-06-27', 'zhaogushu': '--', 'financial_report': None, 'industry_classification': '综合', 'industry_type': '智能矿山系统解决方案、工业智能产品、“北斗+”智慧产品、ERP实施和运维服务、煤气化技术及其相关应用的系统整体方案', 'main_business': '信息化技术服务和煤气化技术推广业务。'}, {'serial_number': 80, 'stock_code': 410, 'stock_abbre': '*ST沈机', 'company_name': '沈阳机床股份有限公司', 'province': '辽宁', 'city': '沈阳市', 'main_bussiness_income': '41.89亿', 'net_profit': '1.08亿', 'employees': 3171, 'listing_date': '1996-07-18', 'zhaogushu': '--', 'financial_report': None, 'ind ...
# (Background on this error at: https://sqlalche.me/e/14/gkpj)
# (pymysql.err.IntegrityError) (1062, "Duplicate entry '81' for key 'PRIMARY'")
# [SQL: INSERT INTO listed_company (serial_number, stock_code, stock_abbre, company_name, province, city, main_bussiness_income, net_profit, employees, listing_date, zhaogushu, financial_report, industry_classification, industry_type, main_business) VALUES (%(serial_number)s, %(stock_code)s, %(stock_abbre)s, %(company_name)s, %(province)s, %(city)s, %(main_bussiness_income)s, %(net_profit)s, %(employees)s, %(listing_date)s, %(zhaogushu)s, %(financial_report)s, %(industry_classification)s, %(industry_type)s, %(main_business)s)]
# [parameters: ({'serial_number': 81, 'stock_code': 411, 'stock_abbre': '英特集团', 'company_name': '浙江英特集团股份有限公司', 'province': '浙江', 'city': '杭州市', 'main_bussiness_income': '189.07亿', 'net_profit': '1.91亿', 'employees': 2800, 'listing_date': '1996-07-16', 'zhaogushu': '--', 'financial_report': None, 'industry_classification': '医药商业', 'industry_type': '医药批发、医药零售', 'main_business': '药品、医疗器械批发及零售业务。'}, {'serial_number': 82, 'stock_code': 413, 'stock_abbre': '东旭光电', 'company_name': '东旭光电科技股份有限公司', 'province': '河北', 'city': '石家庄市', 'main_bussiness_income': '172.77亿', 'net_profit': '19.21亿', 'employees': 3718, 'listing_date': '1996-09-25', 'zhaogushu': '--', 'financial_report': None, 'industry_classification': '显示器件', 'industry_type': '光电显示材料、装备及技术服务、石墨烯产业化应用、新能源汽车、建筑安装、电子通讯产品', 'main_business': '光电显示材料、高端装备制造、新能源汽车制造。'}, {'serial_number': 83, 'stock_code': 415, 'stock_abbre': '渤海租赁', 'company_name': '渤海租赁股份有限公司', 'province': '新疆', 'city': '乌鲁木齐市', 'main_bussiness_income': '359.34亿', 'net_profit': '31.56亿', 'employees': 595, 'listing_date': '1996-07-16', 'zhaogushu': '--', 'financial_report': None, 'industry_classification': '其他非银行金融', 'industry_type': '融资租赁、融资租赁咨询、经营租赁、集装箱租赁、集装箱销售、飞机销售、飞机租赁', 'main_business': '为境内外客户提供全方位的飞机租赁、集装箱租赁、基础设施租赁、大型设备租赁等租赁服务。'}, {'serial_number': 84, 'stock_code': 416, 'stock_abbre': '民生控股', 'company_name': '民生控股股份有限公司', 'province': '山东', 'city': '青岛市', 'main_bussiness_income': '7141.84万', 'net_profit': '2976.15万', 'employees': 47, 'listing_date': '1996-07-19', 'zhaogushu': '--', 'financial_report': None, 'industry_classification': '其他非银行金融', 'industry_type': '典当业务、保险经纪业务、商品零售、其他', 'main_business': '典当业务及保险经纪业务。'}, {'serial_number': 85, 'stock_code': 417, 'stock_abbre': '合肥百货', 'company_name': '合肥百货大楼集团股份有限公司', 'province': '安徽', 'city': '合肥市', 'main_bussiness_income': '103.90亿', 'net_profit': '2.96亿', 'employees': 8166, 'listing_date': '1996-08-12', 'zhaogushu': '--', 'financial_report': None, 'industry_classification': '百货', 'industry_type': '百货业（含家电）、超市业、农产品交易市场、房地产', 'main_business': '零售业、农产品交易市场两大类业务。'}, {'serial_number': 86, 'stock_code': 419, 'stock_abbre': '通程控股', 'company_name': '长沙通程控股股份有限公司', 'province': '湖南', 'city': '长沙市', 'main_bussiness_income': '40.45亿', 'net_profit': '1.48亿', 'employees': 1599, 'listing_date': '1996-08-16', 'zhaogushu': '--', 'financial_report': None, 'industry_classification': '百货', 'industry_type': '商业零售、酒店旅游', 'main_business': '商业零售、酒店旅游、典当、保理。'}, {'serial_number': 87, 'stock_code': 420, 'stock_abbre': '吉林化纤', 'company_name': '吉林化纤股份有限公司', 'province': '吉林', 'city': '吉林市', 'main_bussiness_income': '21.98亿', 'net_profit': '8542.14万', 'employees': 5120, 'listing_date': '1996-08-02', 'zhaogushu': '--', 'financial_report': None, 'industry_classification': '粘胶纤维', 'industry_type': '粘胶长丝、醋酐、粘胶短纤、亚硫酸氢钠', 'main_business': '粘胶纤维的生产和销售。'}, {'serial_number': 88, 'stock_code': 421, 'stock_abbre': '南京公用', 'company_name': '南京公用发展股份有限公司', 'province': '江苏', 'city': '南京市', 'main_bussiness_income': '36.09亿', 'net_profit': '2.49亿', 'employees': 3061, 'listing_date': '1996-08-06', 'zhaogushu': '--', 'financial_report': None, 'industry_classification': '燃气', 'industry_type': '汽车营运、房产开发、汽车销售、旅游服务、燃气销售、工程施工', 'main_business': '燃气销售、房地产开发及客运产业。'}  ... displaying 10 of 20 total bound parameter sets ...  {'serial_number': 99, 'stock_code': 502, 'stock_abbre': '绿景退', 'company_name': '绿景控股股份有限公司', 'province': '广东', 'city': '广州市', 'main_bussiness_income': '2206.13万', 'net_profit': '-8477.38万', 'employees': 142, 'listing_date': '1992-11-23', 'zhaogushu': '--', 'financial_report': None, 'industry_classification': '房地产开发', 'industry_type': '房地产业(房产销售及租赁)、房地产业(物业管理)、医疗服务', 'main_business': '互联网数据中心服务业务。'}, {'serial_number': 100, 'stock_code': 503, 'stock_abbre': '国新健康', 'company_name': '国新健康保障服务集团股份有限公司', 'province': '海南', 'city': '海口市', 'main_bussiness_income': '1.84亿', 'net_profit': '-29.97万', 'employees': 1572, 'listing_date': '1992-11-30', 'zhaogushu': '--', 'financial_report': None, 'industry_classifica ...
# (Background on this error at: https://sqlalche.me/e/14/gkpj)
# (pymysql.err.IntegrityError) (1062, "Duplicate entry '101' for key 'PRIMARY'")
# [SQL: INSERT INTO listed_company (serial_number, stock_code, stock_abbre, company_name, province, city, main_bussiness_income, net_profit, employees, listing_date, zhaogushu, financial_report, industry_classification, industry_type, main_business) VALUES (%(serial_number)s, %(stock_code)s, %(stock_abbre)s, %(company_name)s, %(province)s, %(city)s, %(main_bussiness_income)s, %(net_profit)s, %(employees)s, %(listing_date)s, %(zhaogushu)s, %(financial_report)s, %(industry_classification)s, %(industry_type)s, %(main_business)s)]
# [parameters: ({'serial_number': 101, 'stock_code': 504, 'stock_abbre': '南华生物', 'company_name': '南华生物医药股份有限公司', 'province': '湖南', 'city': '长沙市', 'main_bussiness_income': '6739.30万', 'net_profit': '-3624.92万', 'employees': 539, 'listing_date': '1992-12-08', 'zhaogushu': '--', 'financial_report': None, 'industry_classification': '节能环保', 'industry_type': '节能技术服务、生物医药', 'main_business': '生物医药、节能环保。'}, {'serial_number': 102, 'stock_code': 505, 'stock_abbre': '京粮控股', 'company_name': '海南京粮控股股份有限公司', 'province': '海南', 'city': '海口市', 'main_bussiness_income': '79.18亿', 'net_profit': '2.09亿', 'employees': 2770, 'listing_date': '1992-12-21', 'zhaogushu': '--', 'financial_report': None, 'industry_classification': '房地产开发', 'industry_type': '油脂油料、食品制造', 'main_business': '油脂油料加工销售及贸易和食品制造。'}, {'serial_number': 103, 'stock_code': 506, 'stock_abbre': '中润资源', 'company_name': '中润资源投资股份有限公司', 'province': '山东', 'city': '济南市', 'main_bussiness_income': '7.69亿', 'net_profit': '-4.75亿', 'employees': 1482, 'listing_date': '1993-03-12', 'zhaogushu': '--', 'financial_report': None, 'industry_classification': '黄金', 'industry_type': '房地产、黄金', 'main_business': '以黄金为主要品种的矿业开采与房地产开发建设、销售及自有房产的出租。'}, {'serial_number': 104, 'stock_code': 507, 'stock_abbre': '珠海港', 'company_name': '珠海港股份有限公司', 'province': '广东', 'city': '珠海市', 'main_bussiness_income': '19.60亿', 'net_profit': '1.66亿', 'employees': 5608, 'listing_date': '1993-03-26', 'zhaogushu': '--', 'financial_report': None, 'industry_classification': '港口', 'industry_type': '码头运营服务、物流贸易、物流服务、物业管理、综合能源、饮料食品', 'main_business': '港口的投资、运营以及船舶运输等业务;电力能源、新能源产业以及管道燃气;港城建设、物业管理及生产制造。'}, {'serial_number': 105, 'stock_code': 509, 'stock_abbre': '华塑控股', 'company_name': '华塑控股股份有限公司', 'province': '四川', 'city': '成都市', 'main_bussiness_income': '22.41亿', 'net_profit': '1237.43万', 'employees': 464, 'listing_date': '1993-05-07', 'zhaogushu': '--', 'financial_report': None, 'industry_classification': '其他建材', 'industry_type': '电子产品、医疗服务、房租收入、会展服务收入及其他', 'main_business': '全科医疗服务及舞台美术视觉呈现、视觉工程制作实施等相关业务、电子信息显示终端的研发、设计、生产和销售服务业务。'}, {'serial_number': 106, 'stock_code': 510, 'stock_abbre': '新金路', 'company_name': '四川新金路集团股份有限公司', 'province': '四川', 'city': '德阳市', 'main_bussiness_income': '17.28亿', 'net_profit': '4228.80万', 'employees': 2396, 'listing_date': '1993-05-07', 'zhaogushu': '--', 'financial_report': None, 'industry_classification': '氯碱', 'industry_type': '氯乙烯树脂、碱', 'main_business': '从事PVC树脂和烧碱的生产与销售。'}, {'serial_number': 107, 'stock_code': 513, 'stock_abbre': '丽珠集团', 'company_name': '丽珠医药集团股份有限公司', 'province': '广东', 'city': '珠海市', 'main_bussiness_income': '85.31亿', 'net_profit': '44.88亿', 'employees': 8693, 'listing_date': '1993-10-28', 'zhaogushu': '--', 'financial_report': None, 'industry_classification': '化学制剂', 'industry_type': '化学制剂、生物药、原料药及中间体、中药制剂、诊断试剂及设备', 'main_business': '医药产品的研发、生产及销售。'}, {'serial_number': 108, 'stock_code': 514, 'stock_abbre': '渝开发', 'company_name': '重庆渝开发股份有限公司', 'province': '重庆', 'city': '重庆市', 'main_bussiness_income': '10.41亿', 'net_profit': '9849.10万', 'employees': 831, 'listing_date': '1993-07-12', 'zhaogushu': '--', 'financial_report': None, 'industry_classification': '房地产开发', 'industry_type': '房地产业、租赁和商务服务业', 'main_business': '主要从事房地产开发与销售业务。'}  ... displaying 10 of 20 total bound parameter sets ...  {'serial_number': 119, 'stock_code': 528, 'stock_abbre': '柳工', 'company_name': '广西柳工机械股份有限公司', 'province': '广西', 'city': '柳州市', 'main_bussiness_income': '119.39亿', 'net_profit': '3.69亿', 'employees': 17122, 'listing_date': '1993-11-18', 'zhaogushu': '--', 'financial_report': None, 'industry_classification': '工程机械', 'industry_type': '土石方机械、其他工程机械及配件、融资租赁', 'main_business': '工程机械及关键零部件的研发、生产、销售和服务。'}, {'serial_number': 120, 'stock_code': 529, 'stock_abbre': '广弘控股', 'company_name': '广东广弘控股股份有限公司', 'province': '广东', 'city': '广州市', 'main_bussiness_income': '23.06亿', 'net_profit': '1.56亿', 'employees': 1675, 'listing_date': '1993-11-18', 'zhaogushu': '--', 'financial_report': None, 'industry_classificatio ...
# (Background on this error at: https://sqlalche.me/e/14/gkpj)
# (pymysql.err.IntegrityError) (1062, "Duplicate entry '121' for key 'PRIMARY'")
# [SQL: INSERT INTO listed_company (serial_number, stock_code, stock_abbre, company_name, province, city, main_bussiness_income, net_profit, employees, listing_date, zhaogushu, financial_report, industry_classification, industry_type, main_business) VALUES (%(serial_number)s, %(stock_code)s, %(stock_abbre)s, %(company_name)s, %(province)s, %(city)s, %(main_bussiness_income)s, %(net_profit)s, %(employees)s, %(listing_date)s, %(zhaogushu)s, %(financial_report)s, %(industry_classification)s, %(industry_type)s, %(main_business)s)]
# [parameters: ({'serial_number': 121, 'stock_code': 530, 'stock_abbre': '冰山冷热', 'company_name': '冰山冷热科技股份有限公司', 'province': '辽宁', 'city': '大连市', 'main_bussiness_income': '20.80亿', 'net_profit': '2.05亿', 'employees': 2485, 'listing_date': '1993-12-08', 'zhaogushu': '--', 'financial_report': None, 'industry_classification': '制冷空调设备', 'industry_type': '制冷空调设备', 'main_business': '工业制冷、食品冷冻冷藏、中央及商用空调以及制冷部件等制冷设备的生产和安装。'}, {'serial_number': 122, 'stock_code': 531, 'stock_abbre': '穗恒运A', 'company_name': '广州恒运企业集团股份有限公司', 'province': '广东', 'city': '广州市', 'main_bussiness_income': '29.65亿', 'net_profit': '2.02亿', 'employees': 1230, 'listing_date': '1994-01-06', 'zhaogushu': '--', 'financial_report': None, 'industry_classification': '火电', 'industry_type': '电力、房地产、环保及其他、蒸汽', 'main_business': '电力、热力的生产和销售。'}, {'serial_number': 123, 'stock_code': 532, 'stock_abbre': '华金资本', 'company_name': '珠海华金资本股份有限公司', 'province': '广东', 'city': '珠海市', 'main_bussiness_income': '4.79亿', 'net_profit': '6476.27万', 'employees': 976, 'listing_date': '1994-01-03', 'zhaogushu': '--', 'financial_report': None, 'industry_classification': '电子零部件', 'industry_type': '电子设备制造业、电子器件制造业、公共设施服务业、投资与管理、医疗器械业', 'main_business': '投资与管理、电子设备制造、电子器件制造、水质净化、医疗器械。'}, {'serial_number': 124, 'stock_code': 533, 'stock_abbre': '顺钠股份', 'company_name': '广东顺钠电气股份有限公司', 'province': '广东', 'city': '佛山市', 'main_bussiness_income': '82.67亿', 'net_profit': '6662.72万', 'employees': 1245, 'listing_date': '1994-01-03', 'zhaogushu': '--', 'financial_report': None, 'industry_classification': '厨卫电器', 'industry_type': '输配电设备业务、大宗商品贸易及供应链管理', 'main_business': '输配电设备业务、大宗商品贸易及供应链管理业务。'}, {'serial_number': 125, 'stock_code': 534, 'stock_abbre': '万泽股份', 'company_name': '万泽实业股份有限公司', 'province': '广东', 'city': '汕头市', 'main_bussiness_income': '2.55亿', 'net_profit': '7720.06万', 'employees': 1038, 'listing_date': '1994-01-10', 'zhaogushu': '--', 'financial_report': None, 'industry_classification': '房地产开发', 'industry_type': '微生态活菌产品、高温合金', 'main_business': '微生态活菌产品、高温合金及其制品的研发、生产及销售。'}, {'serial_number': 126, 'stock_code': 536, 'stock_abbre': '华映科技', 'company_name': '华映科技(集团)股份有限公司', 'province': '福建', 'city': '福州市', 'main_bussiness_income': '48.89亿', 'net_profit': '1.98亿', 'employees': 3150, 'listing_date': '1993-11-26', 'zhaogushu': '--', 'financial_report': None, 'industry_classification': '显示器件', 'industry_type': '模组、盖板玻璃、面板', 'main_business': '显示模组业务、盖板玻璃业务、面板业务。'}, {'serial_number': 127, 'stock_code': 537, 'stock_abbre': '广宇发展', 'company_name': '天津中绿电投资股份有限公司', 'province': '天津', 'city': '天津市', 'main_bussiness_income': '216.43亿', 'net_profit': '22.18亿', 'employees': 1519, 'listing_date': '1993-12-10', 'zhaogushu': '--', 'financial_report': None, 'industry_classification': '房地产开发', 'industry_type': '房地产开发、宾馆酒店服务、经营租赁、物业服务', 'main_business': '风能和太阳能投资,开发,运营。'}, {'serial_number': 128, 'stock_code': 538, 'stock_abbre': '云南白药', 'company_name': '云南白药集团股份有限公司', 'province': '云南', 'city': '昆明市', 'main_bussiness_income': '243.15亿', 'net_profit': '31.33亿', 'employees': 8464, 'listing_date': '1993-12-15', 'zhaogushu': '--', 'financial_report': None, 'industry_classification': '中药生产', 'industry_type': '工业产品(自制)、批发零售、农产品、其他服务', 'main_business': '自制工业品的研发、生产和销售，以及药品批发零售业务。'}  ... displaying 10 of 20 total bound parameter sets ...  {'serial_number': 139, 'stock_code': 551, 'stock_abbre': '创元科技', 'company_name': '创元科技股份有限公司', 'province': '江苏', 'city': '苏州市', 'main_bussiness_income': '25.91亿', 'net_profit': '1.35亿', 'employees': 2798, 'listing_date': '1994-01-06', 'zhaogushu': '--', 'financial_report': None, 'industry_classification': '综合', 'industry_type': '设备及工程、输变电高压瓷绝缘子、精密轴承、测绘仪器、磨具磨料、贸易、服务', 'main_business': '洁净环保设备、高压电瓷、轴承滚针、测绘仪器、磨具磨料、代理出口贸易等。'}, {'serial_number': 140, 'stock_code': 552, 'stock_abbre': '靖远煤电', 'company_name': '甘肃靖远煤电股份有限公司', 'province': '甘肃', 'city': '白银市', 'main_bussiness_income': '39.81亿', 'net_profit': '5.53亿', 'employees': 12361, 'listing_date': '1994-01-06', 'zhaogushu': '--', 'financial_report':  ...
# (Background on this error at: https://sqlalche.me/e/14/gkpj)
# (pymysql.err.IntegrityError) (1062, "Duplicate entry '141' for key 'PRIMARY'")
# [SQL: INSERT INTO listed_company (serial_number, stock_code, stock_abbre, company_name, province, city, main_bussiness_income, net_profit, employees, listing_date, zhaogushu, financial_report, industry_classification, industry_type, main_business) VALUES (%(serial_number)s, %(stock_code)s, %(stock_abbre)s, %(company_name)s, %(province)s, %(city)s, %(main_bussiness_income)s, %(net_profit)s, %(employees)s, %(listing_date)s, %(zhaogushu)s, %(financial_report)s, %(industry_classification)s, %(industry_type)s, %(main_business)s)]
# [parameters: ({'serial_number': 141, 'stock_code': 553, 'stock_abbre': '安道麦A', 'company_name': '安道麦股份有限公司', 'province': '湖北', 'city': '荆州市', 'main_bussiness_income': '238.20亿', 'net_profit': '15.46亿', 'employees': 9201, 'listing_date': '1993-12-03', 'zhaogushu': '--', 'financial_report': None, 'industry_classification': '农药', 'industry_type': '除草剂、杀虫剂、杀菌剂、精细化工产品(非农)', 'main_business': '农药、化工产品的制造和销售，农药、化工产品及其中间体的进出口贸易'}, {'serial_number': 142, 'stock_code': 554, 'stock_abbre': '泰山石油', 'company_name': '中国石化山东泰山石油股份有限公司', 'province': '山东', 'city': '泰安市', 'main_bussiness_income': '27.19亿', 'net_profit': '284.67万', 'employees': 1135, 'listing_date': '1993-12-15', 'zhaogushu': '--', 'financial_report': None, 'industry_classification': '石油天然气贸易', 'industry_type': '汽油、柴油、天然气', 'main_business': '主要从事成品油批发零售业务以及非油品业务。'}, {'serial_number': 143, 'stock_code': 555, 'stock_abbre': '神州信息', 'company_name': '神州数码信息服务股份有限公司', 'province': '广东', 'city': '深圳市', 'main_bussiness_income': '81.87亿', 'net_profit': '3.18亿', 'employees': 13361, 'listing_date': '1994-04-08', 'zhaogushu': '--', 'financial_report': None, 'industry_classification': '其他软件服务', 'industry_type': '系统集成、软件开发及技术服务', 'main_business': '技术服务、农业信息化、应用软件开发、金融专用设备相关业务及集成解决方案。'}, {'serial_number': 144, 'stock_code': 557, 'stock_abbre': '西部创业', 'company_name': '宁夏西部创业实业股份有限公司', 'province': '宁夏', 'city': '银川市', 'main_bussiness_income': '6.60亿', 'net_profit': '8699.15万', 'employees': 1111, 'listing_date': '1994-06-17', 'zhaogushu': '--', 'financial_report': None, 'industry_classification': '铁路运输', 'industry_type': '货运、住宿餐饮、葡萄酒', 'main_business': '铁路运输、供应链服务、葡萄酒销售。'}, {'serial_number': 145, 'stock_code': 558, 'stock_abbre': '莱茵体育', 'company_name': '莱茵达体育发展股份有限公司', 'province': '浙江', 'city': '杭州市', 'main_bussiness_income': '13.24亿', 'net_profit': '4496.12万', 'employees': 60, 'listing_date': '1994-05-09', 'zhaogushu': '--', 'financial_report': None, 'industry_classification': '体育运营', 'industry_type': '体育运营、房地产销售及租赁、能源及贸易销售', 'main_business': '体育运营、房地产销售及租赁、能源及贸易销售'}, {'serial_number': 146, 'stock_code': 559, 'stock_abbre': '万向钱潮', 'company_name': '万向钱潮股份公司', 'province': '浙江', 'city': '杭州市', 'main_bussiness_income': '111.54亿', 'net_profit': '9.24亿', 'employees': 7961, 'listing_date': '1994-01-10', 'zhaogushu': '--', 'financial_report': None, 'industry_classification': '汽车零部件', 'industry_type': '汽车零部件', 'main_business': '汽车零部件及相关机电产品的开发、制造和销售。'}, {'serial_number': 147, 'stock_code': 560, 'stock_abbre': '我爱我家', 'company_name': '我爱我家控股集团股份有限公司', 'province': '云南', 'city': '昆明市', 'main_bussiness_income': '13.19亿', 'net_profit': '7576.63万', 'employees': 50493, 'listing_date': '1994-02-02', 'zhaogushu': '--', 'financial_report': None, 'industry_classification': '百货', 'industry_type': '资产管理、经纪业务、新房业务、商品销售、商业租赁及服务、房地产开发、物业服务、旅游服务', 'main_business': '包含房地产经纪服务、房屋资产管理、商业资产管理。'}, {'serial_number': 148, 'stock_code': 561, 'stock_abbre': '烽火电子', 'company_name': '陕西烽火电子股份有限公司', 'province': '陕西', 'city': '宝鸡市', 'main_bussiness_income': '12.17亿', 'net_profit': '8891.02万', 'employees': 2889, 'listing_date': '1994-05-09', 'zhaogushu': '--', 'financial_report': None, 'industry_classification': '通信终端设备', 'industry_type': '短波通信设备、超短波通信设备、航空搜救定位设备、车机内音频控制系统、电声器材', 'main_business': '从事通信装备及电声器材的科研、生产、销售。'}  ... displaying 10 of 20 total bound parameter sets ...  {'serial_number': 159, 'stock_code': 576, 'stock_abbre': '甘化科工', 'company_name': '广东甘化科工股份有限公司', 'province': '广东', 'city': '江门市', 'main_bussiness_income': '4.75亿', 'net_profit': '-2.84亿', 'employees': 326, 'listing_date': '1994-09-07', 'zhaogushu': '--', 'financial_report': None, 'industry_classification': '造纸', 'industry_type': '军工业务、食糖贸易', 'main_business': '食糖贸易业务和电源产品、预制破片等军工产品的研发、生产、销售。'}, {'serial_number': 160, 'stock_code': 581, 'stock_abbre': '威孚高科', 'company_name': '无锡威孚高科技集团股份有限公司', 'province': '江苏', 'city': '无锡市', 'main_bussiness_income': '90.17亿', 'net_profit': '26.47亿', 'employees': 5340, 'listing_date': '1998-09-24', 'zhaogushu': '--', 'financial_r ...
# (Background on this error at: https://sqlalche.me/e/14/gkpj)
# (pymysql.err.IntegrityError) (1062, "Duplicate entry '161' for key 'PRIMARY'")
# [SQL: INSERT INTO listed_company (serial_number, stock_code, stock_abbre, company_name, province, city, main_bussiness_income, net_profit, employees, listing_date, zhaogushu, financial_report, industry_classification, industry_type, main_business) VALUES (%(serial_number)s, %(stock_code)s, %(stock_abbre)s, %(company_name)s, %(province)s, %(city)s, %(main_bussiness_income)s, %(net_profit)s, %(employees)s, %(listing_date)s, %(zhaogushu)s, %(financial_report)s, %(industry_classification)s, %(industry_type)s, %(main_business)s)]
# [parameters: ({'serial_number': 161, 'stock_code': 582, 'stock_abbre': '北部湾港', 'company_name': '北部湾港股份有限公司', 'province': '广西', 'city': '南宁市', 'main_bussiness_income': '37.11亿', 'net_profit': '6.43亿', 'employees': 8378, 'listing_date': '1995-11-02', 'zhaogushu': '--', 'financial_report': None, 'industry_classification': '港口', 'industry_type': '装卸堆存、拖轮及港务管理、物流代理业务、理货业务', 'main_business': '为客户提供集装箱和散杂货的港口装卸、堆存及船舶港口等服务。'}, {'serial_number': 162, 'stock_code': 584, 'stock_abbre': '哈工智能', 'company_name': '江苏哈工智能机器人股份有限公司', 'province': '江苏', 'city': '无锡市', 'main_bussiness_income': '15.72亿', 'net_profit': '1.15亿', 'employees': 1253, 'listing_date': '1995-11-28', 'zhaogushu': '--', 'financial_report': None, 'industry_classification': '氨纶', 'industry_type': '高端装备制造、机器人一站式平台、房地产', 'main_business': '智能制造。'}, {'serial_number': 163, 'stock_code': 585, 'stock_abbre': '东电退', 'company_name': '东北电气发展股份有限公司', 'province': '海南', 'city': '海口市', 'main_bussiness_income': '3298.59万', 'net_profit': '-3.98亿', 'employees': 416, 'listing_date': '1995-12-13', 'zhaogushu': '--', 'financial_report': None, 'industry_classification': '其他输变电设备', 'industry_type': '封闭母线、酒店餐饮住宿业', 'main_business': '输变电设备相关产品的研发、设计、生产和销售及酒店餐饮和住宿业务。'}, {'serial_number': 164, 'stock_code': 586, 'stock_abbre': '汇源通信', 'company_name': '四川汇源光通信股份有限公司', 'province': '四川', 'city': '成都市', 'main_bussiness_income': '3.90亿', 'net_profit': '94.63万', 'employees': 458, 'listing_date': '1995-12-20', 'zhaogushu': '--', 'financial_report': None, 'industry_classification': '通信传输设备', 'industry_type': '光缆产品、通信工程服务', 'main_business': '通信光纤和电力光缆,在线监测,塑料光纤,通信工程施工和高速机电工程。'}, {'serial_number': 165, 'stock_code': 587, 'stock_abbre': '*ST金洲', 'company_name': '金洲慈航集团股份有限公司', 'province': '黑龙江', 'city': '伊春市', 'main_bussiness_income': '116.98亿', 'net_profit': '11.10亿', 'employees': 43, 'listing_date': '1996-04-25', 'zhaogushu': '--', 'financial_report': None, 'industry_classification': '珠宝首饰', 'industry_type': '黄金类业务、铂金类业务、白银类业务、镶嵌类业务、18K金饰品、工艺美术品、融资租赁业务、短融业务、保理业务', 'main_business': '黄金珠宝首饰研发设计、加工制造、批发零售及品牌加盟，融资租赁。'}, {'serial_number': 166, 'stock_code': 589, 'stock_abbre': '贵州轮胎', 'company_name': '贵州轮胎股份有限公司', 'province': '贵州', 'city': '贵阳市', 'main_bussiness_income': '69.60亿', 'net_profit': '-2.22亿', 'employees': 6174, 'listing_date': '1996-03-08', 'zhaogushu': '--', 'financial_report': None, 'industry_classification': '轮胎', 'industry_type': '轮胎', 'main_business': '商用轮胎研发、生产及销售。'}, {'serial_number': 167, 'stock_code': 590, 'stock_abbre': '启迪药业', 'company_name': '启迪药业集团股份公司', 'province': '湖南', 'city': '衡阳市', 'main_bussiness_income': '3.44亿', 'net_profit': '990.60万', 'employees': 1214, 'listing_date': '1996-01-19', 'zhaogushu': '--', 'financial_report': None, 'industry_classification': '中药生产', 'industry_type': '中成药、西药制剂', 'main_business': '研究、开发中国中药传统秘方、验方和西药制剂，生产古汉养生精（口服液、片剂）、养心定悸颗粒、健肾壮腰丸等中成药以及大容量注射剂、原料药、五维赖氨酸口服溶液等西药制剂。'}, {'serial_number': 168, 'stock_code': 591, 'stock_abbre': '太阳能', 'company_name': '中节能太阳能股份有限公司', 'province': '重庆', 'city': '重庆市', 'main_bussiness_income': '52.05亿', 'net_profit': '8.11亿', 'employees': 1859, 'listing_date': '1996-02-08', 'zhaogushu': '--', 'financial_report': None, 'industry_classification': '新能源发电', 'industry_type': '太阳能发电、太阳能产品制造', 'main_business': '太阳能光伏电站的投资运营,以及太阳能电池组件的生产销售。'}  ... displaying 10 of 20 total bound parameter sets ...  {'serial_number': 179, 'stock_code': 605, 'stock_abbre': '渤海股份', 'company_name': '渤海水业股份有限公司', 'province': '北京', 'city': '北京市', 'main_bussiness_income': '16.63亿', 'net_profit': '1.75亿', 'employees': 1382, 'listing_date': '1996-09-13', 'zhaogushu': '--', 'financial_report': None, 'industry_classification': '水务', 'industry_type': '原水、自来水、污水处理、工程、供热、中水处理、污泥处理', 'main_business': '原水和自来水开发供应、管道输水运输、供水设施管理、维护和保养、水务基础设施投资建设及运营管理。'}, {'serial_number': 180, 'stock_code': 606, 'stock_abbre': '*ST顺利', 'company_name': '顺利办信息服务股份有限公司', 'province': '青海', 'city': '西宁市', 'main_bussiness_income': '5.16亿', 'net_profit': '7014.46万', 'employees': 465, 'listing_date ...
# (Background on this error at: https://sqlalche.me/e/14/gkpj)
# (pymysql.err.IntegrityError) (1062, "Duplicate entry '181' for key 'PRIMARY'")
# [SQL: INSERT INTO listed_company (serial_number, stock_code, stock_abbre, company_name, province, city, main_bussiness_income, net_profit, employees, listing_date, zhaogushu, financial_report, industry_classification, industry_type, main_business) VALUES (%(serial_number)s, %(stock_code)s, %(stock_abbre)s, %(company_name)s, %(province)s, %(city)s, %(main_bussiness_income)s, %(net_profit)s, %(employees)s, %(listing_date)s, %(zhaogushu)s, %(financial_report)s, %(industry_classification)s, %(industry_type)s, %(main_business)s)]
# [parameters: ({'serial_number': 181, 'stock_code': 607, 'stock_abbre': '华媒控股', 'company_name': '浙江华媒控股股份有限公司', 'province': '浙江', 'city': '杭州市', 'main_bussiness_income': '18.32亿', 'net_profit': '2.10亿', 'employees': 3124, 'listing_date': '1996-08-30', 'zhaogushu': '--', 'financial_report': None, 'industry_classification': '营销服务', 'industry_type': '广告策划发布、报刊发行与印刷、教育', 'main_business': '经营广告、报刊发行、印刷及新媒体业务、教育培训。'}, {'serial_number': 182, 'stock_code': 608, 'stock_abbre': '阳光股份', 'company_name': '阳光新业地产股份有限公司', 'province': '广西', 'city': '南宁市', 'main_bussiness_income': '5.34亿', 'net_profit': '1.90亿', 'employees': 150, 'listing_date': '1996-09-19', 'zhaogushu': '--', 'financial_report': None, 'industry_classification': '房地产开发', 'industry_type': '开发产品销售、商业租赁、写字楼租赁、商业运营', 'main_business': '商业运营管理业务、物业租赁业务以及住宅、商住尾盘销售业务。'}, {'serial_number': 183, 'stock_code': 609, 'stock_abbre': '中迪投资', 'company_name': '北京中迪投资股份有限公司', 'province': '北京', 'city': '北京市', 'main_bussiness_income': '2.71亿', 'net_profit': '1.34亿', 'employees': 108, 'listing_date': '1996-10-10', 'zhaogushu': '--', 'financial_report': None, 'industry_classification': '综合', 'industry_type': '房地产开发、融资租赁业务', 'main_business': '投资及投资管理、房地产开发和融资租赁。'}, {'serial_number': 184, 'stock_code': 610, 'stock_abbre': '西安旅游', 'company_name': '西安旅游股份有限公司', 'province': '陕西', 'city': '西安市', 'main_bussiness_income': '7.30亿', 'net_profit': '-2012.53万', 'employees': 438, 'listing_date': '1996-09-26', 'zhaogushu': '--', 'financial_report': None, 'industry_classification': '景区', 'industry_type': '旅行社、酒店、商贸', 'main_business': '酒店经营管理、餐饮服务、旅行社、商业地产开发租赁、企业管理咨询、物业管理服务和劳务输出等。'}, {'serial_number': 185, 'stock_code': 611, 'stock_abbre': '天首退', 'company_name': '内蒙古天首科技发展股份有限公司', 'province': '内蒙古', 'city': '包头市', 'main_bussiness_income': '4077.93万', 'net_profit': '-2152.78万', 'employees': 79, 'listing_date': '1996-10-08', 'zhaogushu': '--', 'financial_report': None, 'industry_classification': '纺织', 'industry_type': '动力煤业务、设备租赁、钾肥业务、纺织业、供电、土地租赁', 'main_business': '建设键合材料生产项目、建设钾肥造粒项目'}, {'serial_number': 186, 'stock_code': 612, 'stock_abbre': '焦作万方', 'company_name': '焦作万方铝业股份有限公司', 'province': '河南', 'city': '焦作市', 'main_bussiness_income': '50.17亿', 'net_profit': '1.76亿', 'employees': 2318, 'listing_date': '1996-09-26', 'zhaogushu': '--', 'financial_report': None, 'industry_classification': '铝', 'industry_type': '电解铝液、铝锭及铝合金制品', 'main_business': '铝冶炼及加工，铝制品、金属材料销售。'}, {'serial_number': 187, 'stock_code': 613, 'stock_abbre': '东海A退', 'company_name': '海南大东海旅游中心股份有限公司', 'province': '海南', 'city': '三亚市', 'main_bussiness_income': '2790.66万', 'net_profit': '285.90万', 'employees': 109, 'listing_date': '1997-01-28', 'zhaogushu': '--', 'financial_report': None, 'industry_classification': '酒店', 'industry_type': '旅游饮食服务', 'main_business': '酒店住宿和餐饮服务。'}, {'serial_number': 188, 'stock_code': 615, 'stock_abbre': '奥园美谷', 'company_name': '奥园美谷科技股份有限公司', 'province': '湖北', 'city': '襄阳市', 'main_bussiness_income': '27.95亿', 'net_profit': '4.18亿', 'employees': 3130, 'listing_date': '1996-10-16', 'zhaogushu': '--', 'financial_report': None, 'industry_classification': '房地产开发', 'industry_type': '粘胶系列、房地产销售、医疗美容服务', 'main_business': '纤新材料业务和医疗美容业务。'}  ... displaying 10 of 20 total bound parameter sets ...  {'serial_number': 199, 'stock_code': 629, 'stock_abbre': '钒钛股份', 'company_name': '攀钢集团钒钛资源股份有限公司', 'province': '四川', 'city': '攀枝花市', 'main_bussiness_income': '94.36亿', 'net_profit': '9.20亿', 'employees': 3278, 'listing_date': '1996-11-15', 'zhaogushu': '--', 'financial_report': None, 'industry_classification': '普钢', 'industry_type': '钒、钛、电', 'main_business': '钒产品、钛渣、钛白粉的生产、销售、技术研发和应用开发。'}, {'serial_number': 200, 'stock_code': 630, 'stock_abbre': '铜陵有色', 'company_name': '铜陵有色金属集团股份有限公司', 'province': '安徽', 'city': '铜陵市', 'main_bussiness_income': '824.29亿', 'net_profit': '7.29亿', 'employees': 11832, 'listing_date': '1996-11-20', 'zhaogushu': '--', 'financial_report': None, 'industry_classification': '铜', 'industry_type': '阴极铜、硫酸、黄金、白银、铜箔、铜板带' ...
# (Background on this error at: https://sqlalche.me/e/14/gkpj)
# (pymysql.err.IntegrityError) (1062, "Duplicate entry '201' for key 'PRIMARY'")
# [SQL: INSERT INTO listed_company (serial_number, stock_code, stock_abbre, company_name, province, city, main_bussiness_income, net_profit, employees, listing_date, zhaogushu, financial_report, industry_classification, industry_type, main_business) VALUES (%(serial_number)s, %(stock_code)s, %(stock_abbre)s, %(company_name)s, %(province)s, %(city)s, %(main_bussiness_income)s, %(net_profit)s, %(employees)s, %(listing_date)s, %(zhaogushu)s, %(financial_report)s, %(industry_classification)s, %(industry_type)s, %(main_business)s)]
# ...
# (Background on this error at: https://sqlalche.me/e/14/9h9h)
# (pymysql.err.DataError) (1406, "Data too long for column 'industry_classification' at row 5")
# [SQL: INSERT INTO listed_company (serial_number, stock_code, stock_abbre, company_name, province, city, main_bussiness_income, net_profit, employees, listing_date, zhaogushu, financial_report, industry_classification, industry_type, main_business) VALUES (%(serial_number)s, %(stock_code)s, %(stock_abbre)s, %(company_name)s, %(province)s, %(city)s, %(main_bussiness_income)s, %(net_profit)s, %(employees)s, %(listing_date)s, %(zhaogushu)s, %(financial_report)s, %(industry_classification)s, %(industry_type)s, %(main_business)s)]
# [parameters: ({'serial_number': 1601, 'stock_code': 300077, 'stock_abbre': '国民技术', 'company_name': '国民技术股份有限公司', 'province': '广东', 'city': '深圳市', 'main_bussiness_income': '6.95亿', 'net_profit': '-4.87亿', 'employees': 1060, 'listing_date': '2010-04-30', 'zhaogushu': '--', 'financial_report': None, 'industry_classification': '集成电路', 'industry_type': '安全芯片类产品、通讯芯片类产品', 'main_business': '以信息安全、SoC、无线射频为核心技术发展方向,涵盖IC设计前端至后端全过程技术,产品涉及安全芯片、移动支付整体解决方案、通讯射频芯片及终端产品等多个方向。'}, {'serial_number': 1602, 'stock_code': 300078, 'stock_abbre': '思创医惠', 'company_name': '思创医惠科技股份有限公司', 'province': '浙江', 'city': '杭州市', 'main_bussiness_income': '11.12亿', 'net_profit': '1.31亿', 'employees': 2102, 'listing_date': '2010-04-30', 'zhaogushu': '--', 'financial_report': None, 'industry_classification': '电子零部件', 'industry_type': '商业智能、智慧医疗', 'main_business': 'EAS、RFID相关产品的研发、制造和销售，以及行业应用解决方案的开发、实施和服务。'}, {'serial_number': 1603, 'stock_code': 300079, 'stock_abbre': '数码视讯', 'company_name': '北京数码视讯科技股份有限公司', 'province': '北京', 'city': '北京市', 'main_bussiness_income': '13.50亿', 'net_profit': '4493.31万', 'employees': 709, 'listing_date': '2010-04-30', 'zhaogushu': '--', 'financial_report': None, 'industry_classification': '通信终端设备', 'industry_type': '广播电视信息、金融、通信、特种需求定制', 'main_business': '致力于视频领域技术的自主研发及面向各视频需求相关行业应用，核心技术包括视频处理技术、视频调度技术、视频传输技术、视频安全技术、数字资产加密技术、5G技术AI技术等。'}, {'serial_number': 1604, 'stock_code': 300080, 'stock_abbre': '易成新能', 'company_name': '河南易成新能源股份有限公司', 'province': '河南', 'city': '开封市', 'main_bussiness_income': '18.26亿', 'net_profit': '-10.30亿', 'employees': 4364, 'listing_date': '2010-06-25', 'zhaogushu': '--', 'financial_report': None, 'industry_classification': '非金属新材料', 'industry_type': '新能源业务、新材料业务', 'main_business': '高效单晶硅电池片生产与销售、锂电池的生产与销售、太阳能电站的运营以及超高功率石墨电极、负极材料的生产与销售。'}, {'serial_number': 1605, 'stock_code': 300081, 'stock_abbre': '恒信东方', 'company_name': '恒信东方文化股份有限公司', 'province': '北京', 'city': '北京市', 'main_bussiness_income': '4.31亿', 'net_profit': '9322.24万', 'employees': 580, 'listing_date': '2010-05-20', 'zhaogushu': '--', 'financial_report': None, 'industry_classification': '移动信息产品销售与服务、面向文化、体育和娱乐领域的专业技术服务', 'industry_type': 'LBE城市新娱乐、CG/VR影像内容生产、儿童产业链开发运营、互联网视频应用产品及服务、移动信息产品销售与服务', 'main_business': 'CG及VR内容生产制作、儿童产业链开发运营及LBE(LocationBasedEntertainment)城市新娱乐、移动信息产品的销售与服务'}, {'serial_number': 1606, 'stock_code': 300082, 'stock_abbre': '奥克股份', 'company_name': '辽宁奥克化学股份有限公司', 'province': '辽宁', 'city': '辽阳市', 'main_bussiness_income': '56.99亿', 'net_profit': '2.19亿', 'employees': 1542, 'listing_date': '2010-05-20', 'zhaogushu': '--', 'financial_report': None, 'industry_classification': '其他化学制品', 'industry_type': '建筑化学品板块、新能源材料板块、医疗健康板块', 'main_business': '专注于环氧乙烷、乙烯衍生绿色低碳精细化工高端新材料的研发与生产销售。'}, {'serial_number': 1607, 'stock_code': 300083, 'stock_abbre': '创世纪', 'company_name': '广东创世纪智能装备集团股份有限公司', 'province': '广东', 'city': '东莞市', 'main_bussiness_income': '64.22亿', 'net_profit': '4.61亿', 'employees': 2724, 'listing_date': '2010-05-20', 'zhaogushu': '--', 'financial_report': None, 'industry_classification': '电子零部件', 'industry_type': '高端系列产品、通用系列产品、3C系列产品', 'main_business': '数控机床、高端装备制造和智能制造服务。'}, {'serial_number': 1608, 'stock_code': 300084, 'stock_abbre': '海默科技', 'company_name': '海默科技(集团)股份有限公司', 'province': '甘肃', 'city': '兰州市', 'main_bussiness_income': '5.12亿', 'net_profit': '2524.84万', 'employees': 929, 'listing_date': '2010-05-20', 'zhaogushu': '--', 'financial_report': None, 'industry_classification': '矿山冶金机械', 'industry_type': '多相计量产品及相关服务、井下测/试井及增产仪器、工具及相关服务、压裂设备及相关服务、油田环保设备及相关服务、油气销售', 'main_business': '从事油田高端装备制造及相关服务和油田数字化业务。'}  ... displaying 10 of 20 total bound parameter sets ...  {'serial_number': 1619, 'stock_code': 300096, 'stock_abbre': '易联众', 'company_name': '易联众信息技术股份有限公司', 'province': '福建', 'city': '厦门市', 'main_bussiness_income': '6.26亿', 'net_profit': '2721.63万', 'employees': 3093, 'listing_date': '2010-07-28', 'zhaogushu': '--', 'financial_report': None, 'industry_classification': '行业应用软件', 'industry_type': '民生服务、融资服务、保险 ...
# (Background on this error at: https://sqlalche.me/e/14/9h9h)
# (pymysql.err.DataError) (1406, "Data too long for column 'industry_classification' at row 13")
# [SQL: INSERT INTO listed_company (serial_number, stock_code, stock_abbre, company_name, province, city, main_bussiness_income, net_profit, employees, listing_date, zhaogushu, financial_report, industry_classification, industry_type, main_business) VALUES (%(serial_number)s, %(stock_code)s, %(stock_abbre)s, %(company_name)s, %(province)s, %(city)s, %(main_bussiness_income)s, %(net_profit)s, %(employees)s, %(listing_date)s, %(zhaogushu)s, %(financial_report)s, %(industry_classification)s, %(industry_type)s, %(main_business)s)]
# [parameters: ({'serial_number': 1681, 'stock_code': 300160, 'stock_abbre': '秀强股份', 'company_name': '江苏秀强玻璃工艺股份有限公司', 'province': '江苏', 'city': '宿迁市', 'main_bussiness_income': '13.78亿', 'net_profit': '1.17亿', 'employees': 2628, 'listing_date': '2011-01-13', 'zhaogushu': '--', 'financial_report': None, 'industry_classification': '玻璃', 'industry_type': '玻璃深加工', 'main_business': '以印刷、镀膜、多曲面技术为基础的玻璃深加工产品的研发、生产和销售。'}, {'serial_number': 1682, 'stock_code': 300161, 'stock_abbre': '华中数控', 'company_name': '武汉华中数控股份有限公司', 'province': '湖北', 'city': '武汉市', 'main_bussiness_income': '9.85亿', 'net_profit': '3607.77万', 'employees': 2584, 'listing_date': '2011-01-13', 'zhaogushu': '--', 'financial_report': None, 'industry_classification': '机床设备', 'industry_type': '数控系统与机床、机器人与智能产线、新能源汽车配套、特种装备', 'main_business': '机床数控系统、工业机器人及智能产线、新能源汽车配套业务。'}, {'serial_number': 1683, 'stock_code': 300162, 'stock_abbre': '雷曼光电', 'company_name': '深圳雷曼光电科技股份有限公司', 'province': '广东', 'city': '深圳市', 'main_bussiness_income': '6.45亿', 'net_profit': '2166.72万', 'employees': 1542, 'listing_date': '2011-01-13', 'zhaogushu': '--', 'financial_report': None, 'industry_classification': 'LED', 'industry_type': 'LED、体育', 'main_business': 'LED产业链中下游业务，专注于LED超高清显示及LED照明产业，在业内率先推出并量产基于COB先进集成封装技术的Micro。'}, {'serial_number': 1684, 'stock_code': 300163, 'stock_abbre': '先锋新材', 'company_name': '宁波先锋新材料股份有限公司', 'province': '浙江', 'city': '宁波市', 'main_bussiness_income': '6.89亿', 'net_profit': '-3525.82万', 'employees': 722, 'listing_date': '2011-01-13', 'zhaogushu': '--', 'financial_report': None, 'industry_classification': '其他化学制品', 'industry_type': '遮阳面料、遮阳成品', 'main_business': '从事高分子复合遮阳材料(阳光面料)产品的研发、生产和销售。'}, {'serial_number': 1685, 'stock_code': 300164, 'stock_abbre': '通源石油', 'company_name': '通源石油科技集团股份有限公司', 'province': '陕西', 'city': '西安市', 'main_bussiness_income': '8.17亿', 'net_profit': '5330.52万', 'employees': 558, 'listing_date': '2011-01-13', 'zhaogushu': '--', 'financial_report': None, 'industry_classification': '油田服务', 'industry_type': '石油勘探开发', 'main_business': '油田勘探开发中的钻井、射孔、完井压裂等。'}, {'serial_number': 1686, 'stock_code': 300165, 'stock_abbre': '天瑞仪器', 'company_name': '江苏天瑞仪器股份有限公司', 'province': '江苏', 'city': '苏州市', 'main_bussiness_income': '7.92亿', 'net_profit': '1.15亿', 'employees': 1676, 'listing_date': '2011-01-25', 'zhaogushu': '--', 'financial_report': None, 'industry_classification': '仪器仪表', 'industry_type': '实验分析仪器及系统、环境监测仪器及系统、环保工程及服务、医疗仪器及试剂、第三方检测、运维检测及配件销售', 'main_business': '分析检测仪器、环境监测仪器以及生态治理。'}, {'serial_number': 1687, 'stock_code': 300166, 'stock_abbre': '东方国信', 'company_name': '北京东方国信科技股份有限公司', 'province': '北京', 'city': '北京市', 'main_bussiness_income': '15.06亿', 'net_profit': '4.39亿', 'employees': 8688, 'listing_date': '2011-01-25', 'zhaogushu': '--', 'financial_report': None, 'industry_classification': '行业应用软件', 'industry_type': '数据库及大数据开源系统产品线、工业互联网产品线、公有云产品线、数据科学及人工智能产品线、数据工具及数据应用产品线、地理信息系统及视频管理产品线', 'main_business': '为客户提供企业级大数据、云计算、工业互联网等平台、产品、服务及行业整体解决方案。'}, {'serial_number': 1688, 'stock_code': 300167, 'stock_abbre': '迪威迅', 'company_name': '深圳市迪威迅股份有限公司', 'province': '广东', 'city': '深圳市', 'main_bussiness_income': '5.57亿', 'net_profit': '-1043.31万', 'employees': 929, 'listing_date': '2011-01-25', 'zhaogushu': '--', 'financial_report': None, 'industry_classification': '通信配套服务', 'industry_type': '综合信息化建设、园区建设', 'main_business': '视频通讯技术、产品及行业解决方案的研发、生产、销售。'}  ... displaying 10 of 20 total bound parameter sets ...  {'serial_number': 1699, 'stock_code': 300178, 'stock_abbre': '腾邦退', 'company_name': '腾邦国际商业服务集团股份有限公司', 'province': '广东', 'city': '深圳市', 'main_bussiness_income': '35.30亿', 'net_profit': '3.30亿', 'employees': 254, 'listing_date': '2011-02-15', 'zhaogushu': '--', 'financial_report': None, 'industry_classification': '旅游服务', 'industry_type': '商旅服务、金融服务', 'main_business': '旅游、机票、差旅管理和金融服务。'}, {'serial_number': 1700, 'stock_code': 300179, 'stock_abbre': '四方达', 'company_name': '河南四方达超硬材料股份有限公司', 'province': '河南', 'city': '郑州市', 'main_bussiness_income':  ...
# (Background on this error at: https://sqlalche.me/e/14/9h9h)
# (pymysql.err.DataError) (1406, "Data too long for column 'industry_classification' at row 16")
# [SQL: INSERT INTO listed_company (serial_number, stock_code, stock_abbre, company_name, province, city, main_bussiness_income, net_profit, employees, listing_date, zhaogushu, financial_report, industry_classification, industry_type, main_business) VALUES (%(serial_number)s, %(stock_code)s, %(stock_abbre)s, %(company_name)s, %(province)s, %(city)s, %(main_bussiness_income)s, %(net_profit)s, %(employees)s, %(listing_date)s, %(zhaogushu)s, %(financial_report)s, %(industry_classification)s, %(industry_type)s, %(main_business)s)]
# [parameters: ({'serial_number': 1721, 'stock_code': 300201, 'stock_abbre': '*ST海伦', 'company_name': '徐州海伦哲专用车辆股份有限公司', 'province': '江苏', 'city': '徐州市', 'main_bussiness_income': '15.57亿', 'net_profit': '1.59亿', 'employees': 767, 'listing_date': '2011-04-07', 'zhaogushu': '--', 'financial_report': None, 'industry_classification': '其他专用车辆', 'industry_type': '高空作业车、电源车、抢修车、备件修理、自动集成控制系统、军品、消防车、智能电源', 'main_business': '高空作业车、电力保障车辆、消防车及军品的研发、制造、销售与服务等业务。'}, {'serial_number': 1722, 'stock_code': 300202, 'stock_abbre': '聚龙退', 'company_name': '聚龙股份有限公司', 'province': '辽宁', 'city': '鞍山市', 'main_bussiness_income': '6.83亿', 'net_profit': '5494.39万', 'employees': 1705, 'listing_date': '2011-04-15', 'zhaogushu': '--', 'financial_report': None, 'industry_classification': '专用计算机设备', 'industry_type': '金融电子产品、金融信息化系统开发及服务运营', 'main_business': '金融机具、电子产品销售业务及金融信息化系统开发及服务运营业务。'}, {'serial_number': 1723, 'stock_code': 300203, 'stock_abbre': '聚光科技', 'company_name': '聚光科技(杭州)股份有限公司', 'province': '浙江', 'city': '杭州市', 'main_bussiness_income': '27.99亿', 'net_profit': '5.02亿', 'employees': 6643, 'listing_date': '2011-04-15', 'zhaogushu': '--', 'financial_report': None, 'industry_classification': '环保设备', 'industry_type': '仪器、相关软件及耗材、运营服务、检测服务及咨询服务、环境治理设备及工程', 'main_business': '研发、生产和销售应用于环境监测、工业过程分析等领域的仪器仪表。'}, {'serial_number': 1724, 'stock_code': 300204, 'stock_abbre': '舒泰神', 'company_name': '舒泰神(北京)生物制药股份有限公司', 'province': '北京', 'city': '北京市', 'main_bussiness_income': '13.88亿', 'net_profit': '2.60亿', 'employees': 873, 'listing_date': '2011-04-15', 'zhaogushu': '--', 'financial_report': None, 'industry_classification': '生物医药', 'industry_type': '药品生物制品', 'main_business': '生物药物的研发、生产和营销。'}, {'serial_number': 1725, 'stock_code': 300205, 'stock_abbre': '天喻信息', 'company_name': '武汉天喻信息产业股份有限公司', 'province': '湖北', 'city': '武汉市', 'main_bussiness_income': '19.36亿', 'net_profit': '1147.53万', 'employees': 2331, 'listing_date': '2011-04-21', 'zhaogushu': '--', 'financial_report': None, 'industry_classification': '通信终端设备', 'industry_type': '智能卡、智能终端、税控终端及面向纳税户企业的增值服务、物联网技术服务云平台及增值服务、智慧教育', 'main_business': '金融行业、智能支付终端、物联网、企业服务和K12智慧教育业务。'}, {'serial_number': 1726, 'stock_code': 300206, 'stock_abbre': '理邦仪器', 'company_name': '深圳市理邦精密仪器股份有限公司', 'province': '广东', 'city': '深圳市', 'main_bussiness_income': '8.43亿', 'net_profit': '3792.98万', 'employees': 2440, 'listing_date': '2011-04-21', 'zhaogushu': '--', 'financial_report': None, 'industry_classification': '医疗器械', 'industry_type': '医疗器械', 'main_business': '医疗电子设备产品和体外诊断产品的研发、生产、销售、服务。'}, {'serial_number': 1727, 'stock_code': 300207, 'stock_abbre': '欣旺达', 'company_name': '欣旺达电子股份有限公司', 'province': '广东', 'city': '深圳市', 'main_bussiness_income': '140.45亿', 'net_profit': '5.65亿', 'employees': 36127, 'listing_date': '2011-04-21', 'zhaogushu': '--', 'financial_report': None, 'industry_classification': '电子零部件', 'industry_type': '锂离子电池模组、结构件', 'main_business': '锂离子电池模组的研发、设计、生产及销售。'}, {'serial_number': 1728, 'stock_code': 300208, 'stock_abbre': '青岛中程', 'company_name': '青岛中资中程集团股份有限公司', 'province': '山东', 'city': '青岛市', 'main_bussiness_income': '15.22亿', 'net_profit': '3.33亿', 'employees': 408, 'listing_date': '2011-04-26', 'zhaogushu': '--', 'financial_report': None, 'industry_classification': '电气自控设备', 'industry_type': '电能质量优化、机械成套装备、光伏设备集成、风电设备集成、EPC-服务、EPC-工程、土地出租、物业服务、技术开发、建造业务、材料及其他、贸易业务、其他电子产品销售、代理服务、咨询服务', 'main_business': 'EPC总承包、机械成套装备、物业服务、原料销售、技术开发、采掘服务、煤炭产销、国内外贸易等。'}  ... displaying 10 of 20 total bound parameter sets ...  {'serial_number': 1739, 'stock_code': 300220, 'stock_abbre': '金运激光', 'company_name': '武汉金运激光股份有限公司', 'province': '湖北', 'city': '武汉市', 'main_bussiness_income': '1.85亿', 'net_profit': '-4278.08万', 'employees': 445, 'listing_date': '2011-05-25', 'zhaogushu': '--', 'financial_report': None, 'industry_classification': '电子零部件', 'industry_type': '金属激光、柔性非金属激光、激光熔覆、智能零售终端业务、IP孵化及产品运营业务、渠道运营业务', 'main_business': '高端数字激光装备制造和IP衍生品运营业务。'}, {'serial_number': 1740, 'stock_code': 300221, 'stock_abbre': '银禧科技',  ...
# (Background on this error at: https://sqlalche.me/e/14/9h9h)
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /var/folders/w6/9k4dzqlj617f06dfby_vk1pr0000gn/T/ipykernel_33099/1888878254.py in <module>
#      77 # 单进程
#      78 if __name__ == '__main__':
# ---> 79     main(178)
#      80     endtime = time.time()-start_time
#      81     print('程序运行了%.2f秒' %endtime)
#
# /var/folders/w6/9k4dzqlj617f06dfby_vk1pr0000gn/T/ipykernel_33099/1888878254.py in main(page)
#      71     for i in range(1,page):
#      72         html = get_one_page(i)
# ---> 73         tbl = parse_one_page(html)
#      74         write_to_sql(tbl)
#      75
#
# /var/folders/w6/9k4dzqlj617f06dfby_vk1pr0000gn/T/ipykernel_33099/1888878254.py in parse_one_page(html)
#      34 def parse_one_page(html):
#      35     soup = BeautifulSoup(html,'lxml')
# ---> 36     content = soup.select('#myTable04')[0] #[0]将返回的list改为bs4类型
#      37     tbl = pd.read_html(content.prettify(),header = 0)[0]
#      38     # prettify()优化代码,[0]从pd.read_html返回的list中提取出DataFrame
#
# IndexError: list index out of range

# %% [markdown]
# ## 参考
#
# https://mp.weixin.qq.com/s/xas6OnNrZ_pjLLrqNBuhRA
